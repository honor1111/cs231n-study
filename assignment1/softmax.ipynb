# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
from __future__ import print_function
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.320640
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *W is set randomly, so 1/classes = 1/10 = 0.1, meaning loss = -log(0.1)*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 2.620855 analytic: 2.620855, relative error: 3.026035e-09
# numerical: 1.402604 analytic: 1.402604, relative error: 1.556795e-08
# numerical: -1.040913 analytic: -1.040913, relative error: 4.195316e-08
# numerical: -1.454400 analytic: -1.454400, relative error: 6.239098e-09
# numerical: 1.658089 analytic: 1.658089, relative error: 1.530390e-08
# numerical: 1.207579 analytic: 1.207579, relative error: 1.327799e-08
# numerical: -0.672130 analytic: -0.672130, relative error: 2.034397e-08
# numerical: 1.474038 analytic: 1.474038, relative error: 1.617908e-09
# numerical: -6.008724 analytic: -6.008724, relative error: 5.230237e-10
# numerical: 1.516097 analytic: 1.516097, relative error: 3.129635e-08
# numerical: -0.122926 analytic: -0.122926, relative error: 1.279363e-07
# numerical: 0.236275 analytic: 0.236275, relative error: 5.987925e-08
# numerical: 1.276379 analytic: 1.276379, relative error: 1.658776e-08
# numerical: 1.553044 analytic: 1.553044, relative error: 3.421664e-08
# numerical: -0.131092 analytic: -0.131092, relative error: 6.146705e-08
# numerical: 0.045029 analytic: 0.045029, relative error: 1.551067e-07
# numerical: 5.189362 analytic: 5.189362, relative error: 8.708790e-09
# numerical: -2.342058 analytic: -2.342058, relative error: 8.823292e-09
# numerical: 2.848426 analytic: 2.848426, relative error: 6.399730e-09
# numerical: -0.927478 analytic: -0.927478, relative error: 1.653659e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.320640e+00 computed in 0.078790s
# vectorized loss: 2.320640e+00 computed in 0.002992s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 2e-7, 3e-7, 1e-6, 2e-6, 3e-6]
regularization_strengths = [1e2, 1e3, 1e4, 2.5e4, 5e4, 7.5e4, 10e4, 1e5, 1e6, 1e7]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
pass

iteration = 2000
tic = time.time()

for lr in learning_rates:
    for REG in regularization_strengths:

        sfmx = Softmax()
        sfmx.train(X_train, y_train, learning_rate=lr, reg=REG, num_iters=iteration, verbose=False)

        # predict 
        y_train_pred = sfmx.predict(X_train)
        y_val_pred = sfmx.predict(X_val)

        # scoring
        train_scroe = np.mean(y_train == y_train_pred)
        val_score = np.mean(y_val == y_val_pred)

        # store results
        results[(lr, REG)] = (train_scroe, val_score)

        if best_val < val_score:
            best_val = val_score
            best_softmax = sfmx



################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

toc = time.time()    
print('computed in %fs' % (toc - tic))
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# lr 1.000000e-07 reg 1.000000e+02 train accuracy: 0.261837 val accuracy: 0.254000
# lr 1.000000e-07 reg 1.000000e+03 train accuracy: 0.283653 val accuracy: 0.287000
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.356612 val accuracy: 0.380000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.327776 val accuracy: 0.338000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.310612 val accuracy: 0.325000
# lr 1.000000e-07 reg 7.500000e+04 train accuracy: 0.295776 val accuracy: 0.310000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.290918 val accuracy: 0.303000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.247878 val accuracy: 0.253000
# lr 1.000000e-07 reg 1.000000e+07 train accuracy: 0.111510 val accuracy: 0.100000
# lr 2.000000e-07 reg 1.000000e+02 train accuracy: 0.294429 val accuracy: 0.306000
# lr 2.000000e-07 reg 1.000000e+03 train accuracy: 0.345837 val accuracy: 0.351000
# lr 2.000000e-07 reg 1.000000e+04 train accuracy: 0.358449 val accuracy: 0.368000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.330551 val accuracy: 0.337000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.306837 val accuracy: 0.321000
# lr 2.000000e-07 reg 7.500000e+04 train accuracy: 0.286041 val accuracy: 0.304000
# lr 2.000000e-07 reg 1.000000e+05 train accuracy: 0.281347 val accuracy: 0.290000
# lr 2.000000e-07 reg 1.000000e+06 train accuracy: 0.216959 val accuracy: 0.212000
# lr 2.000000e-07 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.000000e-07 reg 1.000000e+02 train accuracy: 0.318939 val accuracy: 0.331000
# lr 3.000000e-07 reg 1.000000e+03 train accuracy: 0.371673 val accuracy: 0.383000
# lr 3.000000e-07 reg 1.000000e+04 train accuracy: 0.360857 val accuracy: 0.376000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.329143 val accuracy: 0.339000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.299306 val accuracy: 0.317000
# lr 3.000000e-07 reg 7.500000e+04 train accuracy: 0.302898 val accuracy: 0.317000
# lr 3.000000e-07 reg 1.000000e+05 train accuracy: 0.278633 val accuracy: 0.288000
# lr 3.000000e-07 reg 1.000000e+06 train accuracy: 0.245306 val accuracy: 0.233000
# lr 3.000000e-07 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 1.000000e+02 train accuracy: 0.381551 val accuracy: 0.355000
# lr 1.000000e-06 reg 1.000000e+03 train accuracy: 0.403776 val accuracy: 0.406000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.346510 val accuracy: 0.359000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.305286 val accuracy: 0.314000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.285102 val accuracy: 0.299000
# lr 1.000000e-06 reg 7.500000e+04 train accuracy: 0.301857 val accuracy: 0.308000
# lr 1.000000e-06 reg 1.000000e+05 train accuracy: 0.259306 val accuracy: 0.284000
# lr 1.000000e-06 reg 1.000000e+06 train accuracy: 0.108286 val accuracy: 0.106000
# lr 1.000000e-06 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.000000e-06 reg 1.000000e+02 train accuracy: 0.413184 val accuracy: 0.394000
# lr 2.000000e-06 reg 1.000000e+03 train accuracy: 0.401000 val accuracy: 0.398000
# lr 2.000000e-06 reg 1.000000e+04 train accuracy: 0.334163 val accuracy: 0.335000
# lr 2.000000e-06 reg 2.500000e+04 train accuracy: 0.313224 val accuracy: 0.316000
# lr 2.000000e-06 reg 5.000000e+04 train accuracy: 0.277939 val accuracy: 0.289000
# lr 2.000000e-06 reg 7.500000e+04 train accuracy: 0.262429 val accuracy: 0.264000
# lr 2.000000e-06 reg 1.000000e+05 train accuracy: 0.234429 val accuracy: 0.235000
# lr 2.000000e-06 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.000000e-06 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.000000e-06 reg 1.000000e+02 train accuracy: 0.402980 val accuracy: 0.361000
# lr 3.000000e-06 reg 1.000000e+03 train accuracy: 0.386796 val accuracy: 0.386000
# lr 3.000000e-06 reg 1.000000e+04 train accuracy: 0.314551 val accuracy: 0.302000
# lr 3.000000e-06 reg 2.500000e+04 train accuracy: 0.291571 val accuracy: 0.303000
# lr 3.000000e-06 reg 5.000000e+04 train accuracy: 0.248612 val accuracy: 0.254000
# lr 3.000000e-06 reg 7.500000e+04 train accuracy: 0.244551 val accuracy: 0.266000
# lr 3.000000e-06 reg 1.000000e+05 train accuracy: 0.215143 val accuracy: 0.225000
# lr 3.000000e-06 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.000000e-06 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# computed in 450.852699s
# best validation accuracy achieved during cross-validation: 0.406000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.398000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
